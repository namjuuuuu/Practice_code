# %% [markdown]
# #내장함수

# %%
c = "ABC\nDEF"
print(len(c))
# Out:
# 7

# %%
c = round(3.4)
print(c)
# Out:
# 3

# %%
d = [1,2,3]
print(len(d))
# Out:
# 3

# %%
e = [1,[2,3]]
print(len(e))
# Out:
# 2

# %%
f = []
print(len(f))
# Out:
# 0
