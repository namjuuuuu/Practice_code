# %% [markdown]
# <a href="https://colab.research.google.com/github/namjuuuuu/Practice_code/blob/main/Python_3%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3강

# %%
n = 5
type(n)
# Out:
# int

# %%
n = 5.1
type(n)
# Out:
# float

# %%
n1 = 5
n2 = 5.1
n3 = n1 + n2
type(n3)
# Out:
# float

# %%
n = "안녕하세요."
type(n)
# Out:
# str

# %%
n = True
type(n)
# Out:
# bool

# %%
n1 = "안녕하세요."
n2 = '안녕하세요.'
n3 = "A"
n4 = 'A'
n5 = " "
n6 = ' '
print(n1, n2, n3, n4, n5, n6)
# Out:
# 안녕하세요. 안녕하세요. A A

# %%
n1 = """안녕하세요
반갑습니다."""
n2 = '''안녕하세요
반갑습니다.'''
print(n1)
print(n2)
# Out:
# 안녕하세요
# 반갑습니다.
# 안녕하세요
# 반갑습니다.

# %%
print("안녕하세요.\n반갑습니다.")
# Out:
# 안녕하세요.
# 반갑습니다.

# %%
print("안녕하세요.\t반갑습니다.")
# Out:
# 안녕하세요.	반갑습니다.

# %%
print("안녕하세요.\b반갑습니다.")
# Out:
# 반갑습니다.

# %%
print("안녕하세요.\'반갑습니다.")
# Out:
# 안녕하세요.'반갑습니다.

# %%
print("안녕하세요.\\반갑습니다.")
# Out:
# 안녕하세요.\반갑습니다.

# %%
var = "안녕하세요." + "반갑습니다."
print(var)
# Out:
# 안녕하세요.반갑습니다.

# %%
var = "안녕하세요."
var += "반갑습니다."
print(var)
# Out:
# 안녕하세요.반갑습니다.

# %%
var = "안녕하세요."
var += 3
print(var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4179133313.py in <cell line: 0>()
#       1 var = "안녕하세요."
# ----> 2 var += 3
#       3 print(var)
#
# TypeError: can only concatenate str (not "int") to str

# %%
var = "안녕하세요."
var *= 3
print(var)
# Out:
# 안녕하세요.안녕하세요.안녕하세요.

# %%
a = input("단어--> ")
b = input("단어--> ")
c = (a*2) + (b*2)
print(c)
# Out:
# 단어--> 사탕
# 단어--> 초콜릿
# 사탕사탕초콜릿초콜릿

# %%
print("\n")
print("줄바꿈\n연습")
print("\t탭키\t연습")
print("글자가 \"강조\"되는 효과1")
print("글자가 \'강조\'되는 효과2")
print("\\\\\\ 역슬래쉬 세 개 출력")
print("\n"+"\t"+"\\"+"를 그대로 출력")
# Out:
# 줄바꿈
# 연습
# 	탭키	연습
# 글자가 "강조"되는 효과1
# 글자가 '강조'되는 효과2
# \\\ 역슬래쉬 세 개 출력
#
# 	\를 그대로 출력

# %%
print("\n")
print("줄바꿈\n연습")
print("\t탭키\t연습")
print("글자가 \"강조\"되는 효과1")
print("글자가 \'강조\'되는 효과2")
print("\\\\\\ 역슬래쉬 세 개 출력")
print("\\n","\\t","\\"+"를 그대로 출력")
# Out:
# 줄바꿈
# 연습
# 	탭키	연습
# 글자가 "강조"되는 효과1
# 글자가 '강조'되는 효과2
# \\\ 역슬래쉬 세 개 출력
# \n \t \를 그대로 출력

# %%
var = "안녕하세요."
len(var)
# Out:
# 6

# %%
var = "안녕하세요. 반갑습니다!"
len(var)
# Out:
# 13

# %%
var1 = "안녕하세요!"
var2 = "  반갑습니다."
n = len(var1) + len(var2)
print("두 문자열의 길이 합은", n, "입니다.")
# Out:
# 두 문자열의 길이 합은 14 입니다.

# %%
var1 = "apple"
var2 = var1.upper()
print(var2)
# Out:
# APPLE

# %%
var1 = "APPLE"
var2 = var1.lower()
print(var2)
# Out:
# apple

# %%
var1 = "apple이 먹고 싶어요!"
var2 = var1.upper()
print(var2)
# Out:
# APPLE이 먹고 싶어요!

# %%
var = "APPLE"
var.isupper()
# Out:
# True

# %%
var = "APPLE"
var.islower()
# Out:
# False

# %%
var = "APPLE"
var.count("P")
# Out:
# 2

# %%
var = "사과바나나사과메론"
var.count("사과")
# Out:
# 2

# %%
var = "사과바나나사과메론"
var.find("바")
# Out:
# 2

# %%
var = "사과바나나사과메론"
var.find("사과")
# Out:
# 0

# %%
var = "사과바나나사과메론"
var.find("사과", 2)
# Out:
# 5

# %%
var = "사과바나나사과메론"
print(var[0])
# Out:
# 사

# %%
# 잘못된 코드
var = "사과바나나사과메론"
print(var[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3984728236.py in <cell line: 0>()
#       1 # 잘못된 코드
#       2 var = "사과바나나사과메론"
# ----> 3 print(var[10])
#
# IndexError: string index out of range

# %%
ss = "오렌지를 먹고싶어요! Orange.^^"
print("원본 문자열", ss)
ss2 = ss.uppper()
print("모두 대문자로" , ss2)
ss3 = ss.lower()
print("모두 소문자로" , ss3)
ss4 = ss.count()
print("문자의 길이는", ss4)
print("Orange의 시작 위치는", ss.find("Orange"))
# Out:
# 원본 문자열 오렌지를 먹고싶어요! Orange.^^
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2404337268.py in <cell line: 0>()
#       1 ss = "오렌지를 먹고싶어요! Orange.^^"
#       2 print("원본 문자열", ss)
# ----> 3 ss2 = ss.uppper()
#       4 print("모두 대문자로" , ss2)
#       5 ss3 = ss.lower()
#
# AttributeError: 'str' object has no attribute 'uppper'

# %%
ss = "오렌지를 먹고싶어요! Orange. ^^"
print("원본 문자열: ", ss)
ss2 = ss.upper()
print("모두 대문자로: " , ss2)
ss3 = ss.lower()
print("모두 소문자로: " , ss3)
print("문자의 길이는: ", len(ss))
print("Orange의 시작 위치는", ss.find("Orange"))
# Out:
# 원본 문자열:  오렌지를 먹고싶어요! Orange. ^^
# 모두 대문자로:  오렌지를 먹고싶어요! ORANGE. ^^
# 모두 소문자로:  오렌지를 먹고싶어요! orange. ^^
# 문자의 길이는:  22
# Orange의 시작 위치는 12

# %%
ss = "오렌지를 먹고싶어요! Orange. ^^"
print("원본 문자열: ", ss)
print("모두 대문자로: ", ss.upper())
print("모두 소문자로: " , ss.lower())
print("문자의 길이는: ", len(ss))
print("Orange의 시작 위치는", ss.find("Orange"))
# Out:
# 원본 문자열:  오렌지를 먹고싶어요! Orange. ^^
# 모두 대문자로:  오렌지를 먹고싶어요! ORANGE. ^^
# 모두 소문자로:  오렌지를 먹고싶어요! orange. ^^
# 문자의 길이는:  22
# Orange의 시작 위치는 12

# %%
var = "ORAnge"
print("원본 문자열 --> ", var)
var2 = ""
var2 += var[0].lower()
var2 += var[1].lower()
var2 += var[2].lower()
var2 += var[3].upper()
var2 += var[4].upper()
var2 += var[5].upper()
print("변환 문자열 --> ", var2)
# Out:
# 원본 문자열 -->  ORAnge
# 변환 문자열 -->  oraNGE

# %%
str = "안녕하세요"
print("원본 문자열 --> ", str)
str2 = ""
str2 += str[4]
str2 += str[3]
str2 += str[2]
str2 += str[1]
str2 += str[0]
print("변환 문자열 --> ", str2)
# Out:
# 원본 문자열 -->  안녕하세요
# 변환 문자열 -->  요세하녕안
